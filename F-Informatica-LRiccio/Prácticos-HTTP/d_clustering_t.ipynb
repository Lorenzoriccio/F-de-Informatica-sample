# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 

datapath = r'C:\Users\Usuario\Desktop\UNIVERSIDAD\fund_info\Fundamentos_de_informatica\Ciencia_de_datos\iris_data.txt'
iris = pd.read_csv(datapath, sep = '\t')
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
#Desafío I: Averiguá qué variables (columnas) tiene la tabla e inspecioná el DataFrame
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
iris.describe()
#son datos no paramétricos porque la mediana no es igual al promedio
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
datapath = r'C:\Users\Usuario\Desktop\UNIVERSIDAD\fund_info\Fundamentos_de_informatica\Ciencia_de_datos\iris_data.txt'

#Desafío II: Grafica la distribución de frecuencias de la variable "petal.length" ¿Qué información obtenes del gráfico? 
#¿Qué diferencias notás respecto del observado para la variable sepal.length?
sl = sns.histplot(data = iris, x = "sepal.length", binwidth=0.25, kde = True)
plt.show()

# %%
pl = sns.histplot(data = iris, x = "petal.length", binwidth=0.25, kde = True)
plt.show()

# %%
#Grafica la distribución de frecuencias del resto de las variables.
pw = sns.histplot(data = iris, x = "petal.width", binwidth=0.25, kde = True)
plt.show()

# %%
sw = sns.histplot(data = iris, x = "sepal.width", binwidth=0.25, kde = True)
plt.show()

# %%
#Desafío IV: ¿Existe alguna correlación entre algunas de las variables? ¿Cómo te diste cuenta?
import seaborn as sns
g = sns.pairplot(iris) #--> correlatograma (relación entre dif variables)
                    #tiene correlación si su pendiente es positiva, está concentrada y es constante (ex. petal.length)
                    #cálculo entre ptos. se usa el Teorema de Pitágoras

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
iris_escaleado = scaler.fit_transform(iris)

from sklearn.cluster import KMeans, DBSCAN #Para usar kmeans

k = 3  #definimos la cantidad de clusters
kmeans = KMeans(n_clusters = k, init="random", n_init=10, max_iter=300, random_state=123457) #tomamos los centroides de forma aleatoria y definimos un máximo de 300 iteraciones
kmeans.fit(iris_escaleado)  #aplicamos el método a nuestros datos
# Out:
# KMeans(init='random', n_clusters=3, random_state=123457)
