# %%
import pandas as pd
personas =  pd.read_csv(r"C:\Users\Usuario\Desktop\UNIVERSIDAD\fund_info\F-de-Informatica-sample\F-Informatica-LRiccio\Prácticos-Datos\Pandas\personas_2011.csv", sep=";")
# personas.info() --> datos no nulos informacion 
# personas.describe() --> informacion estadistica
# personas.isnull().sum() --> ves cuantos valores nulos hay
personas
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0               1  2011        2    36                         -1
# 1               5  2011        1    48                          1
# 2               7  2011        2    30                          5
# 3              10  2011        2    51                          5
# 4              11  2011        1    39                          2
# ...           ...   ...      ...   ...                        ...
# 68547      185558  2011        2    -1                         -1
# 68548      185574  2011        2    55                         -1
# 68549      185583  2011        2    18                          7
# 68550      185590  2011        2    -1                          8
# 68551      185608  2011        1    27                          5
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                        -1                          -1
# ...

# %%
import seaborn as sns
sns.heatmap(personas.isnull(), cmap='viridis') #--> inspeccion de los datos del df
# personas.dropna(inplace=True) --> elimina columnas con al menos un dato faltante
# personas.dropna(thresh=2, inplace=True) --> elimina columnas con más de un dato faltante
# df.fillna(df['columna_con_faltantes'].mean(), inplace=True) --> reemplaza en el promedio por ex.
# Out:
# <AxesSubplot:>

# %%
# Desafío I: Tomando las tablas de referencia del MinCyT y tomando lo aprendido en el recorrido anterior, incorporá los datos correspondientes a todas las variables categóricas de la tabla

# %%
# Desafío II: Calcular el porcentaje del total de datos, representan los datos nulos de cada columna (variable)
personas.isnull().sum() 
'''Existen 19912 valores nulos en las siguientes columnas:
1. categoria_conicet_id 
2. categoria_incentivos
3. max_dedicacion_horaria_docente_id
4. institucion_cargo_docente_id
5. clase_cargo_docente_id
6. tipo_condicion_docente_id    '''

# %%
# Desafío III: Escribí el código que usarías para reemplazar los faltantes por la moda y por la mediana.
personas.fillna(personas['categoria_conicet_id'].mode(), inplace=True)
personas.fillna(personas['categoria_conicet_id'].median(), inplace=True)
sns.heatmap(personas.isnull(), cmap='viridis')
# no hay nulos más nulos porque fueron reemplazados
# Out:
# <AxesSubplot:>

# %%
# Desafío IV: Revisá el DataFrame para detectar otras anomalías en los datos y averiguá como resolverlas.
